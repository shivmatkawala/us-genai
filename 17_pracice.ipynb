# %% [markdown]
# # Learnig Pandas

# %%
import pandas as pd
df1 = pd.DataFrame({
    "Firstname": ["Alan", "Jaya", "Chinna", "Tamudu", "Babu"],
    "Lastname": ["Pandey", "Samuel", "Ghodke", "Reddy", "Rao"]
})

df1
# Out:
#   Firstname Lastname
# 0      Alan   Pandey
# 1      Jaya   Samuel
# 2    Chinna   Ghodke
# 3    Tamudu    Reddy
# 4      Babu      Rao
