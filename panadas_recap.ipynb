# %% [markdown]
# ##### Practice Pandas:

# %%
import pandas as pd
import openpyxl
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import json

# %% [markdown]
# ###### create a series:

# %%
list1 = [1, 2, 3, 4, 5]

series1 = pd.Series(list1, index=["A", "B", "C", "D", "E"])
series1

# %%
dict1 = {
    "fid": (101, 102, 103, 104),
    "fruit": ("Guava", "Apple", "Grapes", "Mango"),
    "state": ("Telangana", "Kashmir", "Maharashtra", "Gujrat"),
    "price": (140, 200, 250, 500)
}

df1 = pd.DataFrame(dict1)
df1

# %% [markdown]
# ##### Using a sports.txt create a dataframe

# %%
df2 = pd.read_csv("sports.txt")
df2

# %%
df3 = pd.read_excel("american_presidents.xlsx")
df3

# %%
params = quote_plus(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=DESKTOP-MMGIOQB;"
    "DATABASE=genaiDB;"
    "Trusted_connection=yes;"
    "TrustedServerCertificate=yes;"
)

engine = create_engine(
    f"mssql+pyodbc:///?odbc_connect={params}"
)

query = """
    SELECT
        *
    FROM
        samples
"""

df4 = pd.read_sql(query, engine)

df4

# %%
df5 = pd.read_json("preidents.json")
df5

# %%
df4.info()
